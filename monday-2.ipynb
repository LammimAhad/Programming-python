# %%
from astropy.utils.data import download_file
from astropy.io import fits

image_file= download_file('http://data.astropy.org/tutorials/FITS-images/HorseHead.fits',cache=True)
# Out:
# Downloading http://data.astropy.org/tutorials/FITS-images/HorseHead.fits [Done]

# %%
fits.info (image_file)
# Out:
# Filename: /home/csat8303/.astropy/cache/download/py2/2c9202ae878ecfcb60878ceb63837f5f
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     161   (891, 893)   int16
#   1  er.mask     TableHDU        25   1600R x 4C   [F6.2, F6.2, F6.2, F6.2]

# %%
image_data= fits.getdata(image_file, ext=0)
image_data.shape
# Out:
# (893, 891)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.imshow(image_data, cmap='gist_heat', origin='lower')
plt.colorbar();

# %%
hdulist= fits.open(image_file)
hdulist.info()
# Out:
# Filename: /home/csat8303/.astropy/cache/download/py2/2c9202ae878ecfcb60878ceb63837f5f
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     161   (891, 893)   int16
#   1  er.mask     TableHDU        25   1600R x 4C   [F6.2, F6.2, F6.2, F6.2]

# %%
header = hdulist['PRIMARY'].header
data = hdulist['PRIMARY'].data

hdulist.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-f3780eef32ab> in <module>()
#       1 header = hdulist['PRIMARY'].header
# ----> 2 data = hdulist['PRIMARY'].data
#       3
#       4 hdulist.close()
#
# /home/csat8303/anaconda2/lib/python2.7/site-packages/astropy/utils/decorators.pyc in __get__(self, obj, owner)
#     720             return obj.__dict__[self._key]
#     721         except KeyError:
# --> 722             val = self.fget(obj)
#     723             obj.__dict__[self._key] = val
#     724             return val
#
# /home/csat8303/anaconda2/lib/python2.7/site-packages/astropy/io/fits/hdu/image.pyc in data(self)
#     241             return
#     242
# --> 243         data = self._get_scaled_image_data(self._data_offset, self.shape)
#     244         self._update_header_scale_info(data.dtype)
#     245
#
# /home/csat8303/anaconda2/lib/python2.7/site-packages/astropy/io/fits/hdu/image.pyc in _get_scaled_image_data(self, offset, shape)
#     698         code = BITPIX2DTYPE[self._orig_bitpix]
#     699
# --> 700         raw_data = self._get_raw_data(shape, code, offset)
#     701         raw_data.dtype = raw_data.dtype.newbyteorder('>')
#     702
#
# /home/csat8303/anaconda2/lib/python2.7/site-packages/astropy/io/fits/hdu/base.pyc in _get_raw_data(self, shape, code, offset)
#     476                               offset=offset)
#     477         elif self._file:
# --> 478             return self._file.readarray(offset=offset, dtype=code, shape=shape)
#     479         else:
#     480             return None
#
# /home/csat8303/anaconda2/lib/python2.7/site-packages/astropy/io/fits/file.pyc in readarray(self, size, offset, dtype, shape)
#     253                                  '{}'.format(size, shape, dtype))
#     254
# --> 255         filepos = self._file.tell()
#     256
#     257         try:
#
# ValueError: I/O operation on closed file

# %%
print(repr(header[:10]))
# Out:
# SIMPLE  =                    T /FITS: Compliance
# BITPIX  =                   16 /FITS: I*2 Data
# NAXIS   =                    2 /FITS: 2-D Image Data
# NAXIS1  =                  891 /FITS: X Dimension
# NAXIS2  =                  893 /FITS: Y Dimension
# EXTEND  =                    T /FITS: File can contain extensions
# DATE    = '2014-01-09        '  /FITS: Creation Date
# ORIGIN  = 'STScI/MAST'         /GSSS: STScI Digitized Sky Survey
# SURVEY  = 'SERC-ER '           /GSSS: Sky Survey
# REGION  = 'ER768   '           /GSSS: Region Name

# %%
print (header[:10].keys())
print (header[:10].values())
print (header['ORIGIN'])
# Out:
# ['SIMPLE', 'BITPIX', 'NAXIS', 'NAXIS1', 'NAXIS2', 'EXTEND', 'DATE', 'ORIGIN', 'SURVEY', 'REGION']
# [True, 16, 2, 891, 893, True, '2014-01-09', 'STScI/MAST', 'SERC-ER', 'ER768']
# STScI/MAST

# %%
from astropy.wcs import WCS
wcs= WCS(header)

print wcs
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 85.599416666666656  -4.9466388888888888
# CRPIX : -716.333144294269  -8444.6494669822605
# PC1_1 PC1_2  : 0.015029018460682027  -9.6373577765719806e-06
# PC2_1 PC2_2  : 1.0548917307845708e-05  0.015000473845055023
# CDELT : -0.018654788242111486  0.018654788242111486
# NAXIS : 891  893

# %%
fig = plt.figure()
ax= fig.add_axes([0.1,0.1,0.8,0.8], projection=wcs)
ax.set_xlabel('RA')
ax.set_ylabel('Dec')
ax.imshow(data, cmap='gist_heat', origin='lower')
ra = ax.coords[0]
ra.set_major_formatter('hh:mm:ss')
dec = ax.coords[1]
dec.set_major_formatter('dd:mm:ss')

# %%
from astropy.coordinates import SkyCoord
c0= SkyCoord('5h41m00s','-2d27m00s', frame='icrs')
print c0
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     ( 85.25, -2.45)>

# %%
#ra, dec = 

center = wcs.all_world2pix(c0.ra, c0.dec,0)
print(center)
# Out:
# [array(534.1235215073059), array(475.5504697035576)]

# %%
from astropy.nddata import Cutout2D
size= 500
cutout = Cutout2D(data, center, size, wcs=wcs)

print cutout.bbox_original
# Out:
# ((226, 725), (284, 783))

# %%
fig = plt.figure()
ax= fig.add_axes([0.1,0.1,0.8,0.8], projection=cutout.wcs)
ax.set_xlabel('RA')
ax.set_ylabel('Dec')
ax.imshow(cutout.data, cmap='gist_heat', origin='lower')
ra = ax.coords[0]
ra.set_major_formatter('hh:mm:ss')
dec = ax.coords[1]
dec.set_major_formatter('dd:mm:ss')

# %%
cheader = cutout.wcs.to_header()
primaryhdu = fits.PrimaryHDU(cutout.data, cheader)
hdulist = fits.HDUList([primaryhdu])
hdulist.writeto('horse.fits', overwrite=True)
